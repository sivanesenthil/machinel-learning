# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("coaster_db.csv")

# %%
df.shape
# Out:
# (1087, 56)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df=df.drop(["speed1"],axis=1)

# %%
df.shape
# Out:
# (1087, 55)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df1=df[['coaster_name',  'Location',  'Status', 'Manufacturer','year_introduced',
       'opening_date_clean', 
       'speed_mph', 'height_value',
       'Inversions_clean', 'Gforce_clean','Type_Main']].copy()

# %% [markdown]
# df1.shape

# %%
df1.shape
# Out:
# (1087, 11)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# opening_date_clean     object
# speed_mph             float64
# height_value          float64
# Inversions_clean        int64
# Gforce_clean          float64
# Type_Main              object
# dtype: object

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
pd.to_datetime(df["opening_date_clean"])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %% [markdown]
# df1=df1.rename(column={'coaster_name': "Coaster_name",'year_introduced':'Year_introduced'})

# %% [raw]
# df1 =df1.rename(column={'coaster_namei': 'Coaster_name'})

# %%
df1 =df1.rename(columns={'coaster_name': 'Coaster_name'})

# %%
df1.columns
# Out:
# Index(['Coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'opening_date_clean', 'speed_mph', 'height_value', 'Inversions_clean',
#        'Gforce_clean', 'Type_Main'],
#       dtype='object')

# %%
df1.isna()
# Out:
#       Coaster_name  Location  Status  Manufacturer  year_introduced  \
# 0            False     False   False         False            False
# 1            False     False   False         False            False
# 2            False     False   False          True            False
# 3            False     False   False         False            False
# 4            False     False   False         False            False
# ...            ...       ...     ...           ...              ...
# 1082         False     False    True         False            False
# 1083         False     False   False         False            False
# 1084         False     False    True         False            False
# 1085         False     False   False         False            False
# 1086         False     False   False         False            False
#
#       opening_date_clean  speed_mph  height_value  Inversions_clean  \
# 0                  False      False         False             False
# ...

# %%
df1.isna().sum()
# Out:
# Coaster_name            0
# Location                0
# Status                213
# Manufacturer           59
# year_introduced         0
# opening_date_clean    250
# speed_mph             150
# height_value          122
# Inversions_clean        0
# Gforce_clean          725
# Type_Main               0
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df1.loc[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_name, Location, Status, Manufacturer, year_introduced, opening_date_clean, speed_mph, height_value, Inversions_clean, Gforce_clean, Type_Main]
# Index: []

# %%
df1.loc[df1.duplicated(subset="Coaster_name")].head(2)
# Out:
#              Coaster_name            Location   Status        Manufacturer  \
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 60            Derby Racer        Revere Beach  Removed      Fred W. Pearce
#
#     year_introduced opening_date_clean  speed_mph  height_value  \
# 43             1927         1926-01-01       60.0          96.0
# 60             1937         1911-01-01        NaN           NaN
#
#     Inversions_clean  Gforce_clean Type_Main
# 43                 0           4.0      Wood
# 60                 0           NaN      Wood

# %%
df1.query('Coaster_name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     year_introduced opening_date_clean  speed_mph  height_value  \
# 39             1926         1926-01-01       60.0          96.0
# 43             1927         1926-01-01       60.0          96.0
#
#     Inversions_clean  Gforce_clean Type_Main
# 39                 0           4.0      Wood
# 43                 0           4.0      Wood

# %%
df1.duplicated(subset=["Coaster_name","Location","opening_date_clean"]).sum()
# Out:
# 97

# %%
df1 = df1.loc[df1.duplicated(subset=["Coaster_name","Location","opening_date_clean"])].reset_index(drop=True)

# %%
df1.shape
# Out:
# (97, 11)

# %%
df1.head(45)
# Out:
#                                   Coaster_name                Location  \
# 0                        Crystal Beach Cyclone      Crystal Beach Park
# 1                                  Derby Racer            Revere Beach
# 2                  Blue Streak (Conneaut Lake)      Conneaut Lake Park
# 3                Big Thunder Mountain Railroad                   Other
# 4            Thunder Run (Canada's Wonderland)     Canada's Wonderland
# 5                                    La Vibora                   Other
# 6                Big Thunder Mountain Railroad                   Other
# 7                                    La Vibora                   Other
# 8         Flashback (Six Flags Magic Mountain)                   Other
# 9                               Alpine Bobsled                   Other
# 10          Ultra Twister (Nagashima Spa Land)      Nagashima Spa Land
# 11                   Ultra Twister (Six Flags)                   Other
# ...

# %%
ax= df1['year_introduced'].value_counts().head(10).plot()

# %%
df1['year_introduced'].value_counts().head(10).plot(kind='bar',title="top year")
ax.set_xlabel("Year_introduced")
ax.set_ylabel("count")
# Out:
# Text(4.444444444444452, 0.5, 'count')

# %%
df1['speed_mph'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ax=df1['speed_mph'].plot(kind='hist',bins=20,title="speed(mph)")
ax.set_xlabel('speed(mph)')
# Out:
# Text(0.5, 0, 'speed(mph)')

# %%
#kernal density plot
ax=df1['speed_mph'].plot(kind='kde',title='speed(mph)')
ax.set_xlabel("speed(mph)")
# Out:
# Text(0.5, 0, 'speed(mph)')

# %%
df.plot(kind='scatter',x='speed_mph',y='height_value',title='coaster speed vs height')
plt.show()

# %%
ax=sns.scatterplot(x='speed_mph',y='height_value',data=df1)
ax.set_title('coaster speed vs. height')
plt.show()

# %%
sns.pairplot(df1,
             vars=['year_introduced','speed_mph','height_value','Inversions_clean','Gforce_clean'],hue="Type_Main")
plt.show()

# %%
df_corr = df1[['year_introduced','speed_mph','height_value']].dropna().corr()
df_corr
# Out:
#                  year_introduced  speed_mph  height_value
# year_introduced         1.000000   0.083632      0.060479
# speed_mph               0.083632   1.000000      0.800656
# height_value            0.060479   0.800656      1.000000

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.query('Location != "Other"')
# Out:
#                           Coaster_name                         Location  \
# 0                Crystal Beach Cyclone               Crystal Beach Park
# 1                          Derby Racer                     Revere Beach
# 2          Blue Streak (Conneaut Lake)               Conneaut Lake Park
# 4    Thunder Run (Canada's Wonderland)              Canada's Wonderland
# 10  Ultra Twister (Nagashima Spa Land)               Nagashima Spa Land
# 16               Wild Mouse (Idlewild)           Idlewild and Soak Zone
# 35                 Journey to Atlantis                 SeaWorld Orlando
# 40        Flying Fish (roller coaster)                      Thorpe Park
# 41                 Journey to Atlantis                 SeaWorld Orlando
# 45            Wipeout (roller coaster)               Pleasurewood Hills
# 49          Afterburn (roller coaster)                        Carowinds
# 52                   Superman The Ride            Six Flags New England
# ...
